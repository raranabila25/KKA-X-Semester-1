# %% [markdown]
# <a href="https://colab.research.google.com/github/raranabila25/KKA-X-Semester-1/blob/main/%221_Fungsi_print_RaraX_6ipymb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rara Khanza Ghalin Nabila

# %% [markdown]
# Absen:32

# %% [markdown]
# Kelas:X-6

# %% [markdown]
# #Menampilkan Teks Bebas

# %%
print('halo rara imut')
# Out:
# halo rara imut

# %%
print("Rara Khanza Ghalin Nabila")
# Out:
# Rara Khanza Ghalin Nabila

# %%
print("""
Nama:Rara
Kelas:x-6
""")
# Out:
# Nama:Rara
# Kelas:x-6

# %%
print("""
Haloo dunia
aku hari ini belajar bahasa python
""")
# Out:
# Haloo dunia
# aku hari ini belajar bahasa python

# %% [markdown]
# #Menampilkan nilai variabel

# %%
Nama = "Rara Khanza Ghalin Nabila"
Usia = 15

print(Nama)
print(Usia)
# Out:
# Rara Khanza Ghalin Nabila
# 15

# %%
Warna_favorit = "pink coquete"
Berat_badan = 52

print(Warna_favorit)
print(Berat_badan)
# Out:
# pink coquete
# 52

# %% [markdown]
# #Menampilkan teks bebas dan nilai variabel

# %%
print("Nama:" + Nama
)
# Out:
# Nama:Rara Khanza Ghalin Nabila

# %%
print("Berat_badan:" + str(Berat_badan))
# Out:
# Berat_badan:52

# %%
print("Nama:", Nama, "loh")
# Out:
# Nama: Rara Khanza Ghalin Nabila loh

# %%
print("berat badan:", beratbadan)
# Out:
# berat badan: 52

# %%
print(f"Nama: {Nama} loh")
# Out:
# Nama: Rara Khanza Ghalin Nabila loh

# %% [markdown]
# #Escape Character

# %%
print("""Nama: Rara Khanza Ghalin Nabila
Kelas: X.6
No.Absen:32""")
# Out:
# Nama: Rara Khanza Ghalin Nabila
# Kelas: X.6
# No.Absen:32

# %%
print("Nama:Rara Khanza Ghalin Nabila")
print("kelas: X.6")
print("No.Absen: 32")
# Out:
# Nama:Rara Khanza Ghalin Nabila
# kelas: X.6
# No.Absen: 32

# %%
print("Nama: Rara Khanza Ghalin Nabila\nKelas: X.6\nNo. Asen\t: 32")
# Out:
# Nama: Rara Khanza Ghalin Nabila
# Kelas: X.6
# No. Asen	: 32

# %%
print("Nama\t\t: Rara Khanza Ghalin Nabila\nKelas\t\t: X.6\nNo. Absen\t: 32")
# Out:
# Nama		: Rara Khanza Ghalin Nabila
# Kelas		: X.6
# No. Absen	: 32

# %%
print('Nama\t\t: Ra\'ra Khanza\nkelas\t\t: X.6\nNo. Absen\t: 32')
# Out:
# Nama		: Ra'ra Khanza
# kelas		: X.6
# No. Absen	: 32

# %%
print("Nama\t\t: Ra'ra Khanza\nKelas\t\t: X.6\nNo. Absen\t: 32")
# Out:
# Nama		: Ra'ra Khanza
# Kelas		: X.6
# No. Absen	: 32

# %%
print("Lokasi file tugas KKA: C:\\KKA\\Tugas Rara")
# Out:
# Lokasi file tugas KKA: C:\KKA\Tugas Rara

# %%
print("Bu Shinta berkata,\"Tolong perhatikan ke layar Tv!\".")
# Out:
# Bu Shinta berkata,"Tolong perhatikan ke layar Tv!".

# %%
print('Bu Sninta berkata,"Tolong perhatikan ke layar.TV!".')
# Out:
# Bu Sninta berkata,"Tolong perhatikan ke layar.TV!".

# %% [markdown]
# #parameter fungsi print

# %%
tahun=2000
bulan = "Februari"
tanggal=18

print(tahun, end="-")
print(bulan, end="-")
print(tanggal)
# Out:
# 2000-Februari-18

# %%
print(tanggal, end="/")
print(bulan, end="/")
print(tahun)
# Out:
# 18/Februari/2000

# %%
nama_siswa_1 = "Fida"
nama_siswa_2 = "Aji"
nama_siswa_3 = "Hadziq"

print(nama_siswa_2, end="~")
print(nama_siswa_3, end="~")
print(nama_siswa_1,)
# Out:
# Aji~Hadziq~Fida

# %%
print(nama_siswa_1, nama_siswa_2, nama_siswa_3, sep="~")
# Out:
# Fida~Aji~Hadziq

# %%
print(nama_siswa_3, nama_siswa_1,nama_siswa_2, sep="-")
# Out:
# Hadziq-Fida-Aji
