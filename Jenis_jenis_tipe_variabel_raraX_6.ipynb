# %% [markdown]
# <a href="https://colab.research.google.com/github/raranabila25/KKA-X-Semester-1/blob/main/Jenis_jenis_tipe_variabel_raraX_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Rara Khanza Ghalin Nabila
# Kelas: X-6
# Absent: 32

# %% [markdown]
# #Jenis Tipe Variabel

# %%
a = "Hadziq"
print(a)
type(a)
# Out:
# Hadziq
# str

# %%
b = 1.9
print(b)
type(b)
# Out:
# 1.9
# float

# %%
c = -9
print(c)
type(c)
# Out:
# -9
# int

# %%
d = True
print(d)
type(d)
# Out:
# True
# bool

# %%
e = "False"
print(e)
type(e)
# Out:
# False
# str

# %%
f = 5,2
print(f)
type(f)
# Out:
# (5, 2)
# tuple

# %%
type(6.99)
# Out:
# float

# %% [markdown]
# #Mengubah Tipe Variabel

# %%
g = 8
print(g)
type(g)
# Out:
# 8
# int

# %%
g = float(g)
print(g)
type(g)
# Out:
# 8.0
# float

# %%
g = str(g)
print(g)
type(g)
# Out:
# 8.0
# str

# %%
g = bool(g)
print(g)
type(g)
# Out:
# True
# bool

# %%
h = 0.0
print(h)
type(h)
# Out:
# 0.0
# float

# %%
h = bool(h)
print(h)
type(h)
# Out:
# False
# bool

# %%
y = 6.9
print(y)
type(y)
# Out:
# 6.9
# float

# %%
x = int(y)
print(x)
type(x)
# Out:
# 6
# int

# %%
k = int(6.99)
print
t

# %% [markdown]
# #Operator Perbandingan

# %%
print(6>=6)
# Out:
# True

# %%
print(8==9)
# Out:
# False

# %%
print(8!=9)
# Out:
# True

# %%
print(8<10)
# Out:
# True

# %%
print(8>10)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(not(5<=5))
# Out:
# False

# %%
print(8>7 and 6<5)
# Out:
# False

# %%
print(7<=1 or 2!=2)
# Out:
# False

# %%
print(not(0= =1 and 1!=1)
# Out:
#   File "/tmp/ipython-input-3018481435.py", line 1
#     print(not(0= =1 and 1!=1)
#                ^
# SyntaxError: invalid syntax

# %%
print(not(5 < 10 or 5 < = 10)
# Out:
#   File "/tmp/ipython-input-3325539751.py", line 1
#     print(not(5 < 10 or 5 < = 10)
#                             ^
# SyntaxError: invalid syntax
