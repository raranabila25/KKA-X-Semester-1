# %% [markdown]
# <a href="https://colab.research.google.com/github/raranabila25/KKA-X-Semester-1/blob/main/Tipe_Variabel_Rara_khanza_X_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Rara Khanza Ghalin Nabila
#
# Kelas:X-6
#
# No.absent:32

# %% [markdown]
# #konsep dasar variabel

# %%
print("shintahanafia.2025@gmail.com")
print("shintahanafia.2025@gmail.com")
print("shintahanafia.2025@gmail.com")
print("shintahanafia.2025@gmail.com")
# Out:
# shintahanafia.2025@gmail.com
# shintahanafia.2025@gmail.com
# shintahanafia.2025@gmail.com
# shintahanafia.2025@gmail.com

# %%
email_user_1 = "shintahanafia.2025@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# shintahanafia.2025@gmail.com
# shintahanafia.2025@gmail.com
# shintahanafia.2025@gmail.com
# shintahanafia.2025@gmail.com

# %% [markdown]
# #peraturan penulisan variabel

# %%
#penulisan vatiabel hanya boleh huruf,angka,dan unsercore
#email user 1 = "shintahanafia.2025@gmail.com"

emailuser1 = "shintahanafia.2025@gmail.com"
print(emailuser1)
# Out:
# shintahanafia.2025@gmail.com

# %%
#Tidak boleh didahului oleh angka
1emailuser = "shintahanafia.2025@gmail.com"
print(1emailuser)
# Out:
#   File "/tmp/ipython-input-891630111.py", line 2
#     1emailuser = "shintahanafia.2025@gmail.com"
#     ^
# SyntaxError: invalid decimal literal

# %%
#penulisan variabel itu case sensitif

nama_siswa_1 = "shinta hanafia"
print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3991445309.py in <cell line: 0>()
#       2
#       3 nama_siswa_1 = "shinta hanafia"
# ----> 4 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
#Hanya boleh menggunakan angka,huruf,dan underscore
berat badan = 60

Print(berat badan)
# Out:
#   File "/tmp/ipython-input-125173002.py", line 2
#     berat badan = 60
#           ^
# SyntaxError: invalid syntax

# %%
beratbadan = 60
print(beratbadan)
# Out:
# 60

# %%
#Tidak boleh diawali dengan angka
1_nama_ortu_siswa = "budi"
print(nama_ortu_siswa_1)
# Out:
#   File "/tmp/ipython-input-1254794858.py", line 2
#     1_nama_ortu_siswa = "budi"
#      ^
# SyntaxError: invalid decimal literal

# %%
nama_ortu_siswa_1 = "budi"
print(nama_ortu_siswa_1)
# Out:
# budi

# %%
namaortusiswa1 = "adi"
print(namaortusiswa1)
# Out:
# adi

# %%
# Tidak boleh menggunakan kata kunci pyhton
if = "Aji Mulyono"
# Out:
#   File "/tmp/ipython-input-1886255689.py", line 2
#     if = "Aji Mulyono"
#        ^
# SyntaxError: invalid syntax

# %%
IF = "Aji Mulyono"
print(IF)
# Out:
# Aji Mulyono

# %%
print= "Muhammad syakoer"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-325487071.py in <cell line: 0>()
#       1 print= "Muhammad syakoer"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
print = "Muhammad syakoer"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3140608168.py in <cell line: 0>()
#       1 print = "Muhammad syakoer"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
# Sensitif terhadap kapital
USIA = 16
Print(Usia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1745059501.py in <cell line: 0>()
#       1 # Sensitif terhadap kapital
#       2 USIA = 16
# ----> 3 Print(Usia)
#
# NameError: name 'Print' is not defined

# %%
print(USIA)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2412020416.py in <cell line: 0>()
# ----> 1 print(USIA)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #Assignment

# %%
#Single Assigment
usia = 18
print(usia)
# Out:
# 18

# %%
#Multiple Assignment
nama_siswa, usia_siswa = "budi", 16
print(nama_siswa)
print(usia_siswa)
# Out:
# budi
# 16

# %%
p,q,r = 1,2,"hello"
print(r)
print(q)
print(p)
# Out:
# hello
# 2
# 1

# %%
p,q,r = 1,2,"hello","shinta"
print(r)
print(p)
print(q)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-261852800.py in <cell line: 0>()
# ----> 1 p,q,r = 1,2,"hello","shinta"
#       2 print(r)
#       3 print(p)
#       4 print(q)
#
# ValueError: too many values to unpack (expected 3)

# %%
p,q,r = 1,2,"hello","shinta"
print(r)
print(p)
print(q)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-261852800.py in <cell line: 0>()
# ----> 1 p,q,r = 1,2,"hello","shinta"
#       2 print(r)
#       3 print(p)
#       4 print(q)
#
# ValueError: too many values to unpack (expected 3)

# %%
#Chain Assigment
nilai_ayyas = nilai_hadziq = 100
print(nilai_ayyas)
print(nilai_hadziq)
# Out:
# 100
# 100

# %% [markdown]
# #penulisan operator di pyhton

# %%
#Tanpa Variabel
print(100+10)
# Out:
# 110

# %%
#Operand disimpen ke variabel
telur_ayam_chanifa = 100
telur_ayam_shinta = 10
print(telur_ayam_chanifa + telur_ayam_shinta)
# Out:
# 110

# %%
#Hasil operasi disimpen ke variabel
total_telur_ayam = 100+10
print(total_telur_ayam)
# Out:
# 110

# %%
#Operand dan hasil operasi di simpan ke variabel
telur_ayam_chanifa = 100
telur_ayam_shinta = 10

total_telur_ayam = telur_ayam_chanifa + telur_ayam_shinta
Print(total_telur_ayam)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2872180060.py in <cell line: 0>()
#       4
#       5 total_telur_ayam = telur_ayam_chanifa + telur_ayam_shinta
# ----> 6 Print(total_telur_ayam)
#
# NameError: name 'Print' is not defined
